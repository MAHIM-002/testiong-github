# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHIM-002/testiong-github/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df= pd.read_csv('/content/heart disease classification dataset.csv')

# %%
df
# Out:
#      Unnamed: 0  age     sex  cp  trestbps   chol  fbs  restecg  thalach  \
# 0             0   63    male   3     145.0  233.0    1        0    150.0
# 1             1   37    male   2     130.0  250.0    0        1    187.0
# 2             2   41  female   1     130.0  204.0    0        0    172.0
# 3             3   56    male   1     120.0  236.0    0        1    178.0
# 4             4   57  female   0       NaN  354.0    0        1    163.0
# ..          ...  ...     ...  ..       ...    ...  ...      ...      ...
# 298         298   57  female   0     140.0  241.0    0        1    123.0
# 299         299   45    male   3     110.0  264.0    0        1    132.0
# 300         300   68    male   0     144.0  193.0    1        1    141.0
# 301         301   57    male   0       NaN  131.0    0        1    115.0
# 302         302   57  female   1     130.0  236.0    0        0    174.0
#
#      exang  oldpeak  slope  ca  thal target
# 0        0      2.3      0   0     1    yes
# ...

# %%
df.shape
# Out:
# (303, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   age         303 non-null    int64
#  2   sex         303 non-null    object
#  3   cp          303 non-null    int64
#  4   trestbps    299 non-null    float64
#  5   chol        302 non-null    float64
#  6   fbs         303 non-null    int64
#  7   restecg     303 non-null    int64
#  8   thalach     298 non-null    float64
#  9   exang       303 non-null    int64
#  10  oldpeak     303 non-null    float64
#  11  slope       303 non-null    int64
#  12  ca          303 non-null    int64
#  13  thal        303 non-null    int64
#  14  target      303 non-null    object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 35.6+ KB

# %%
df=df.dropna()

# %%
df
# Out:
#      Unnamed: 0  age     sex  cp  trestbps   chol  fbs  restecg  thalach  \
# 0             0   63    male   3     145.0  233.0    1        0    150.0
# 1             1   37    male   2     130.0  250.0    0        1    187.0
# 2             2   41  female   1     130.0  204.0    0        0    172.0
# 3             3   56    male   1     120.0  236.0    0        1    178.0
# 5             5   57    male   0     140.0  192.0    0        1    148.0
# ..          ...  ...     ...  ..       ...    ...  ...      ...      ...
# 296         296   63  female   0     124.0  197.0    0        1    136.0
# 298         298   57  female   0     140.0  241.0    0        1    123.0
# 299         299   45    male   3     110.0  264.0    0        1    132.0
# 300         300   68    male   0     144.0  193.0    1        1    141.0
# 302         302   57  female   1     130.0  236.0    0        0    174.0
#
#      exang  oldpeak  slope  ca  thal target
# 0        0      2.3      0   0     1    yes
# ...

# %%
df.shape
# Out:
# (293, 15)

# %%
df.describe()
# Out:
#        Unnamed: 0         age          cp    trestbps        chol         fbs  \
# count  293.000000  293.000000  293.000000  293.000000  293.000000  293.000000
# mean   150.877133   54.348123    0.965870  131.679181  246.177474    0.146758
# std     86.860137    9.182042    1.033114   17.658077   51.405545    0.354470
# min      0.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.000000   47.000000    0.000000  120.000000  211.000000    0.000000
# 50%    151.000000   55.000000    1.000000  130.000000  240.000000    0.000000
# 75%    226.000000   61.000000    2.000000  140.000000  275.000000    0.000000
# max    302.000000   77.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  293.000000  293.000000  293.000000  293.000000  293.000000  293.000000
# mean     0.518771  149.880546    0.331058    1.054266    1.392491    0.730375
# ...

# %%
import matplotlib.pyplot as plt

# %%
x= df['age']
y= df['slope']
plt.scatter(x,y,c='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x= df['age']
y= df['oldpeak']
plt.scatter(x,y,c='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x= df['age']
y= df['thalach']
plt.scatter(x,y,c='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x= df['age']
y= df['cp']
plt.scatter(x,y,c='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import numpy as np
